# %% [markdown]
# <a href="https://colab.research.google.com/github/Alex-Roberts27/PRSJaxProject/blob/main/PRSJaxData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pgs_id= PGS004008
# 1. SOURCE INFORMATION
# 1. pgp_id= PGP000517
# 2. citation= Monti R et al. Am J Hum Genet (2024). doi:10.1016/j.ajhg.2024.06.003
#
#
# ---
#
#
#
# pgs_id=PGS003957
# 1. SOURCE INFORMATION
# 2. pgp_id=PGP000503
# 3. citation=Sofer T et al. Alzheimers Res Ther (2023). doi:10.1186/s13195-023-01298-3
#
#
# ---
#
# pgs_id=PGS004589
# 1. SOURCE INFORMATION
# 2. pgp_id=PGP000567
# 3. citation=Jung SH et al. JAMA Netw Open (2022). doi:10.1001/jamanetworkopen.2022.47162
#
#
# ---
# pgs_id=PGS004590
# 1. SOURCE INFORMATION
# 2. pgp_id=PGP000569
# 3. citation=Lake J et al. Mol Psychiatry (2023). doi:10.1038/s41380-023-02089-w
#
#
# ---
# pgs_id=PGS004062
# 1. SOURCE INFORMATION
# 2. pgp_id=PGP000517
# 3. citation=Monti R et al. Am J Hum Genet (2024). doi:10.1016/j.ajhg.2024.06.003

# %% [markdown]
# ## to do
# 1. find way to import file
# 2. find way to clean and check data
# 3. find way to rank scores by most positive values
# 4. see which values = which snps -> those are the snps which have the highest impact on developing alzheimers in population set used
#
# **also**
# 1.  compare snps in differnet ethnicities, i.e. snps in europeans vs snps in asians

# %%
# import the stack!
import pandas as pd
import numpy as np
from scipy.stats import chisquare
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# typical Data Cleaning stack
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler,MinMaxScaler,OrdinalEncoder,OneHotEncoder
from sklearn.impute import SimpleImputer

# %%
file1 = pd.read_csv('PRSDataEuropean.txt') #loads  file into variable
#print(file1.iloc[1:3])  ##shows top 4 rows of data
print(file1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5677 entries, 0 to 5676
# Data columns (total 1 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information  5677 non-null   object
# dtypes: object(1)
# memory usage: 44.5+ KB
# None

# %%
file2 = pd.read_csv('PRSDataEastAsian.txt') #loads  file into variable
#print(file2.iloc[1:3])  ##shows top 4 rows of data
print(file2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 1 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information  94 non-null     object
# dtypes: object(1)
# memory usage: 884.0+ bytes
# None

# %%
file3 = pd.read_csv('PRSDataHispanic.txt') #loads  file into variable
#print(file3.iloc[1:3])  ##shows top 4 rows of data
print(file3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12016 entries, 0 to 12015
# Data columns (total 1 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information  12016 non-null  object
# dtypes: object(1)
# memory usage: 94.0+ KB
# None

# %%
file4 = pd.read_csv('PRSDataEuropeanLarge.txt') #loads  file into variable
#print(file4.iloc[1:3])  ##shows top 4 rows of data
print(file4.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691150 entries, 0 to 691149
# Data columns (total 1 columns):
#  #   Column                                                                                                             Non-Null Count   Dtype
# ---  ------                                                                                                             --------------   -----
#  0   ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information  691150 non-null  object
# dtypes: object(1)
# memory usage: 5.3+ MB
# None

# %%
file5 = pd.read_csv('PRSDataMultiAncestry.txt') #loads  file into variable
#print(file5.iloc[1:3])  ##shows top 4 rows of data
print(file5.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 1 columns):
#  #   Column                                                                                                             Non-Null Count  Dtype
# ---  ------                                                                                                             --------------  -----
#  0   ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information  377 non-null    object
# dtypes: object(1)
# memory usage: 3.1+ KB
# None

# %%
# how much missing data is there in each of these columns?
print(file1.isnull().sum())
print("~"*50)
print(file2.isnull().sum())
print("~"*50)
print(file3.isnull().sum())
print("~"*50)
print(file4.isnull().sum())
print("~"*50)
print(file5.isnull().sum())
# Out:
# ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information    0
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information    0
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information    0
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information    0
# dtype: int64
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ###PGS CATALOG SCORING FILE - see https://www.pgscatalog.org/downloads/#dl_ftp_scoring for additional information    0
# dtype: int64

# %%
File1CSV = pd.read_csv('PRSDataEuropean.txt', sep='\t', comment='#')
File1CSV.to_csv('PRSEuropean.csv', index=False)
File1CSV.head()
# Out:
#          rsID  chr_name  chr_position effect_allele other_allele  \
# 0   rs9803031         1       1051820             C            T
# 1   rs2488991         1       1059011             G            T
# 2   rs9442398         1       1086315             A            G
# 3   rs4970362         1       1159358             A            G
# 4  rs11260556         1       1194826             A            G
#
#    effect_weight
# 0      -0.000346
# 1      -0.002233
# 2      -0.000481
# 3      -0.001497
# 4       0.001280

# %%
File1CSV.isnull().sum()
# Out:
# rsID             0
# chr_name         0
# chr_position     0
# effect_allele    0
# other_allele     0
# effect_weight    0
# dtype: int64

# %%
# drop duplicate rows
dup = File1CSV.duplicated(keep='first')
dropped = File1CSV.loc[dup]

if not dropped.empty:
    print(f"Found {len(dropped)} duplicate rows.")
    print(dropped['rsID'].unique()[0]) # Still useful if duplicates are found to show an example.
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
File2CSV = pd.read_csv('PRSDataEastAsian.txt', sep='\t', comment='#')
File2CSV.to_csv('PRSEastAsian.csv', index=False)
File2CSV.head()
# Out:
#           rsID effect_allele  effect_weight
# 0   rs56983910             T        -0.3818
# 1   rs12640503             A         0.1096
# 2  rs117807585             A        -0.2335
# 3  rs142802245             A         0.0944
# 4   rs76367405             A         0.2116

# %%
File2CSV.isnull().sum()
# Out:
# rsID             0
# effect_allele    0
# effect_weight    0
# dtype: int64

# %%
dup = File2CSV.duplicated(keep='first')
dropped = File2CSV.loc[dup]

if not dropped.empty:
    print(f"Found {len(dropped)} duplicate rows.")
    print(dropped['rsID'].unique()[0]) # Still useful if duplicates are found to show an example.
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
File3CSV = pd.read_csv('PRSDataHispanic.txt', sep='\t', comment='#')
File3CSV.to_csv('PRSHispanic.csv', index=False)
File3CSV.head()
# Out:
#    chr_name  chr_position effect_allele other_allele  effect_weight
# 0         1     207577223             T            C         0.1508
# 1         2     127068957             A            G        -0.0897
# 2         2     127088929             T            C        -0.1213
# 3         2     127128075             A            G        -0.1231
# 4         2     127131181             A            C        -0.1404

# %%
File3CSV.isnull().sum()
# Out:
# chr_name         0
# chr_position     0
# effect_allele    0
# other_allele     0
# effect_weight    0
# dtype: int64

# %%
dup = File3CSV.duplicated(keep='first')
dropped = File3CSV.loc[dup]

if not dropped.empty:
    print(f"Found {len(dropped)} duplicate rows.")
    print(dropped['rsID'].unique()[0]) # Still useful if duplicates are found to show an example.
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
File4CSV = pd.read_csv('PRSDataEuropeanLarge.txt', sep='\t', comment='#')
File4CSV.to_csv('PRSEuropeanLarge.csv', index=False)
File4CSV.head()
# Out:
#          rsID  chr_name  chr_position effect_allele other_allele  \
# 0   rs3131972         1        817341             A            G
# 1   rs3131969         1        818802             A            G
# 2   rs3131967         1        818954             T            C
# 3   rs1048488         1        825532             C            T
# 4  rs12562034         1        833068             A            G
#
#    effect_weight
# 0       0.000183
# 1       0.000110
# 2       0.000083
# 3       0.000080
# 4      -0.000288

# %%
File4CSV.isnull().sum()
# Out:
# rsID             0
# chr_name         0
# chr_position     0
# effect_allele    0
# other_allele     0
# effect_weight    0
# dtype: int64

# %%
dup = File4CSV.duplicated(keep='first')
dropped = File4CSV.loc[dup]

if not dropped.empty:
    print(f"Found {len(dropped)} duplicate rows.")
    print(dropped['rsID'].unique()[0]) # Still useful if duplicates are found to show an example.
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
File5CSV = pd.read_csv('PRSDataMultiAncestry.txt', sep='\t', comment='#')
File5CSV.to_csv('PRSMultiAncestry.csv', index=False)
File5CSV.head()
# Out:
#          rsID  chr_name  chr_position effect_allele other_allele  \
# 0  rs34779859         2     127892768             G            T
# 1   rs9787874        11      85860305             G            A
# 2   rs1532278         8      27466315             T            C
# 3  rs12151021        19       1050874             A            G
# 4  rs10779336         1     207798716             T            G
#
#    effect_weight variant_description
# 0        -0.1196    p-value=8.82E-47
# 1        -0.0968    p-value=1.74E-39
# 2        -0.0987    p-value=1.28E-38
# 3         0.1028    p-value=3.90E-33
# 4         0.1153    p-value=2.64E-32

# %%
File5CSV.isnull().sum()
# Out:
# rsID                   0
# chr_name               0
# chr_position           0
# effect_allele          0
# other_allele           0
# effect_weight          0
# variant_description    0
# dtype: int64

# %%
dup = File5CSV.duplicated(keep='first')
dropped = File5CSV.loc[dup]

if not dropped.empty:
    print(f"Found {len(dropped)} duplicate rows.")
    print(dropped['rsID'].unique()[0]) # Still useful if duplicates are found to show an example.
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
print(File1CSV.describe())
# Out:
#           chr_name  chr_position  effect_weight
# count  5663.000000  5.663000e+03    5663.000000
# mean      9.266113  7.453599e+07      -0.000044
# std       6.055203  5.578367e+07       0.002064
# min       1.000000  1.623290e+05      -0.071810
# 25%       4.000000  3.036955e+07      -0.000282
# 50%       8.000000  6.027491e+07       0.000005
# 75%      14.000000  1.086763e+08       0.000298
# max      22.000000  2.479823e+08       0.034083

# %%
print(File2CSV.describe())
# Out:
#        effect_weight
# count      80.000000
# mean       -0.005135
# std         0.107243
# min        -0.381800
# 25%        -0.087900
# 50%        -0.056500
# 75%         0.081000
# max         0.211600

# %%
print(File3CSV.describe())
# Out:
#            chr_name  chr_position  effect_weight
# count  12002.000000  1.200200e+04   12002.000000
# mean       8.982003  7.714370e+07       0.002457
# std        5.947316  5.752445e+07       0.123581
# min        1.000000  6.893400e+04      -0.668000
# 25%        4.000000  3.099479e+07      -0.077300
# 50%        8.000000  6.503689e+07       0.038600
# 75%       13.000000  1.126838e+08       0.082375
# max       22.000000  2.488073e+08       0.948600

# %%
print(File4CSV.describe())
# Out:
#             chr_name  chr_position  effect_weight
# count  691136.000000  6.911360e+05   6.911360e+05
# mean        8.927634  7.785975e+07   7.373297e-07
# std         5.901554  5.695924e+07   3.196567e-04
# min         1.000000  1.570300e+04  -1.191500e-01
# 25%         4.000000  3.115521e+07  -2.383300e-05
# 50%         8.000000  6.799084e+07   1.642250e-07
# 75%        13.000000  1.139211e+08   2.518600e-05
# max        22.000000  2.489172e+08   8.417600e-02

# %%
print(File5CSV.describe())
# Out:
#          chr_name  chr_position  effect_weight
# count  363.000000  3.630000e+02     363.000000
# mean     9.661157  7.101660e+07      -0.004395
# std      5.879857  5.422024e+07       0.053732
# min      1.000000  3.961560e+05      -0.152100
# 25%      5.000000  3.045878e+07      -0.047700
# 50%      9.000000  5.517626e+07      -0.032100
# 75%     15.000000  1.024758e+08       0.040850
# max     22.000000  2.419674e+08       0.129800

# %% [markdown]
# now have to rank each file by most positive effect weight, show then top 10 rsIDs
# 1. File1CSV - Europeans
# 2. File2CSV - East Asian
# 3. File3CSV - Hispanic
# 4. File4CSV - European Large
# 5. File5CSV - MultiAncestry

# %%
##pull File1CSV
#rank weights by most positive value
#show rsIDs corresponding to most positive values
